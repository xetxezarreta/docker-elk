# %%
import pandas as pd

df = pd.read_csv('data/data_metricbeat.csv')
df.head()
# Out:
#                     @timestamp  @version                   _id  \
# 0  Jan 16, 2020 @ 13:44:07.691         1  HfGYrm8B0x4jmF2o0sqe
# 1  Jan 16, 2020 @ 13:44:07.501         1  HPGYrm8B0x4jmF2o0sqe
# 2  Jan 16, 2020 @ 13:44:07.247         1  GvGYrm8B0x4jmF2ozsoJ
# 3  Jan 16, 2020 @ 13:44:06.776         1  GfGYrm8B0x4jmF2ozsoJ
# 4  Jan 16, 2020 @ 13:44:06.700         1  GPGYrm8B0x4jmF2ozsoJ
#
#              _index  _score _type                    agent.ephemeral_id  \
# 0  metricbeat-7.5.0     NaN  _doc  575ec2ef-3d69-40b9-8e89-a807dc165087
# 1  metricbeat-7.5.0     NaN  _doc  575ec2ef-3d69-40b9-8e89-a807dc165087
# 2  metricbeat-7.5.0     NaN  _doc  835758b3-9c3d-4afb-9fcc-bb46662886bf
# 3  metricbeat-7.5.0     NaN  _doc  835758b3-9c3d-4afb-9fcc-bb46662886bf
# 4  metricbeat-7.5.0     NaN  _doc  835758b3-9c3d-4afb-9fcc-bb46662886bf
#
#                   agent.hostname                              agent.id  \
# 0  ip-172-31-90-184.ec2.internal  33503d10-1273-4439-bc6a-41a3bcfba6ef
# ...

# %%
df.columns.values
# Out:
# array(['@timestamp', '@version', '_id', '_index', '_score', '_type',
#        'agent.ephemeral_id', 'agent.hostname', 'agent.id', 'agent.type',
#        'agent.version', 'cloud.account.id', 'cloud.availability_zone',
#        'cloud.image.id', 'cloud.instance.id', 'cloud.machine.type',
#        'cloud.provider', 'cloud.region', 'destination.ip',
#        'destination.port', 'ecs.version', 'event.dataset',
#        'event.duration', 'event.module', 'host.architecture',
#        'host.containerized', 'host.hostname', 'host.name',
#        'host.os.codename', 'host.os.family', 'host.os.kernel',
#        'host.os.name', 'host.os.platform', 'host.os.version',
#        'metricset.name', 'metricset.period', 'network.direction',
#        'network.iana_number', 'network.type', 'process.args',
#        'process.executable', 'process.name', 'process.pgid',
#        'process.pid', 'process.ppid', 'process.working_directory',
#        'server.ip', 'server.port', 'service.type', 'source.ip',
# ...

# %%
df = df.dropna(axis='columns')
df.head()
# Out:
#                     @timestamp  @version                   _id  \
# 0  Jan 16, 2020 @ 13:44:07.691         1  HfGYrm8B0x4jmF2o0sqe
# 1  Jan 16, 2020 @ 13:44:07.501         1  HPGYrm8B0x4jmF2o0sqe
# 2  Jan 16, 2020 @ 13:44:07.247         1  GvGYrm8B0x4jmF2ozsoJ
# 3  Jan 16, 2020 @ 13:44:06.776         1  GfGYrm8B0x4jmF2ozsoJ
# 4  Jan 16, 2020 @ 13:44:06.700         1  GPGYrm8B0x4jmF2ozsoJ
#
#              _index _type                    agent.ephemeral_id  \
# 0  metricbeat-7.5.0  _doc  575ec2ef-3d69-40b9-8e89-a807dc165087
# 1  metricbeat-7.5.0  _doc  575ec2ef-3d69-40b9-8e89-a807dc165087
# 2  metricbeat-7.5.0  _doc  835758b3-9c3d-4afb-9fcc-bb46662886bf
# 3  metricbeat-7.5.0  _doc  835758b3-9c3d-4afb-9fcc-bb46662886bf
# 4  metricbeat-7.5.0  _doc  835758b3-9c3d-4afb-9fcc-bb46662886bf
#
#                   agent.hostname                              agent.id  \
# 0  ip-172-31-90-184.ec2.internal  33503d10-1273-4439-bc6a-41a3bcfba6ef
# ...

# %%
df.columns.values
# Out:
# array(['@timestamp', '@version', '_id', '_index', '_type',
#        'agent.ephemeral_id', 'agent.hostname', 'agent.id', 'agent.type',
#        'agent.version', 'cloud.account.id', 'cloud.availability_zone',
#        'cloud.image.id', 'cloud.instance.id', 'cloud.machine.type',
#        'cloud.provider', 'cloud.region', 'ecs.version', 'event.dataset',
#        'event.duration', 'event.module', 'host.architecture',
#        'host.containerized', 'host.hostname', 'host.name',
#        'host.os.codename', 'host.os.family', 'host.os.kernel',
#        'host.os.name', 'host.os.platform', 'host.os.version',
#        'metricset.name', 'metricset.period', 'service.type', 'tags'],
#       dtype=object)
