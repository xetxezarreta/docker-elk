# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data/data_metricbeat1.csv')
df.shape
# Out:
# (13730, 182)

# %%
cols = [
    # duration
    'event.duration',
    # cpu
    'system.cpu.cores', 
    'system.cpu.idle.pct',
    'system.cpu.iowait.pct', 
    'system.cpu.irq.pct',
    'system.cpu.nice.pct', 
    'system.cpu.softirq.pct',
    'system.cpu.steal.pct', 
    'system.cpu.system.pct',
    'system.cpu.total.pct', 
    'system.cpu.user.pct',
    # memory
    'system.memory.actual.free', 
    'system.memory.actual.used.bytes',
    'system.memory.actual.used.pct', 
    'system.memory.free',
    'system.memory.hugepages.free', 
    'system.memory.hugepages.reserved',
    'system.memory.hugepages.surplus',
    'system.memory.hugepages.swap.out.fallback',
    'system.memory.hugepages.swap.out.pages',
    'system.memory.hugepages.total',
    'system.memory.hugepages.used.bytes',
    'system.memory.hugepages.used.pct', 
    'system.memory.swap.free',
    'system.memory.swap.in.pages', 
    'system.memory.swap.out.pages',
    'system.memory.swap.readahead.cached',
    'system.memory.swap.readahead.pages', 
    'system.memory.swap.total',
    'system.memory.swap.used.bytes', 
    'system.memory.swap.used.pct',
    'system.memory.total', 
    'system.memory.used.bytes',
    'system.memory.used.pct'    
]

cpu_cols = [
    # duration
    'event.duration',
    # cpu
    'system.cpu.cores', 
    'system.cpu.idle.pct',
    'system.cpu.iowait.pct', 
    'system.cpu.irq.pct',
    'system.cpu.nice.pct', 
    'system.cpu.softirq.pct',
    'system.cpu.steal.pct', 
    'system.cpu.system.pct',
    'system.cpu.total.pct', 
    'system.cpu.user.pct'
]

memory_cols = [
    # duration
    'event.duration',
    # memory
    'system.memory.actual.free', 
    'system.memory.actual.used.bytes',
    'system.memory.actual.used.pct', 
    'system.memory.free',
    'system.memory.hugepages.free', 
    'system.memory.hugepages.reserved',
    'system.memory.hugepages.surplus',
    'system.memory.hugepages.swap.out.fallback',
    'system.memory.hugepages.swap.out.pages',
    'system.memory.hugepages.total',
    'system.memory.hugepages.used.bytes',
    'system.memory.hugepages.used.pct', 
    'system.memory.swap.free',
    'system.memory.swap.in.pages', 
    'system.memory.swap.out.pages',
    'system.memory.swap.readahead.cached',
    'system.memory.swap.readahead.pages', 
    'system.memory.swap.total',
    'system.memory.swap.used.bytes', 
    'system.memory.swap.used.pct',
    'system.memory.total', 
    'system.memory.used.bytes',
    'system.memory.used.pct'    
]

# %%
df[cols].describe()
# Out:
#        system.cpu.cores  system.cpu.idle.pct  system.cpu.iowait.pct  \
# count            1077.0          1077.000000            1077.000000
# mean                1.0             0.992766               0.000072
# std                 0.0             0.060790               0.000434
# min                 1.0             0.000000               0.000000
# 25%                 1.0             0.996000               0.000000
# 50%                 1.0             0.997000               0.000000
# 75%                 1.0             0.998000               0.000000
# max                 1.0             1.000000               0.010000
#
#        system.cpu.irq.pct  system.cpu.nice.pct  system.cpu.softirq.pct  \
# count              1077.0               1077.0             1077.000000
# mean                  0.0                  0.0                0.000027
# std                   0.0                  0.0                0.000162
# min                   0.0                  0.0                0.000000
# 25%                   0.0                  0.0                0.000000
# 50%                   0.0                  0.0                0.000000
# 75%                   0.0                  0.0                0.000000
# max                   0.0                  0.0                0.001000
#
#        system.cpu.steal.pct  system.cpu.system.pct  system.cpu.total.pct  \
# count           1077.000000            1077.000000           1077.000000
# mean               0.000551               0.000352              0.003448
# std                0.002893               0.000658              0.004122
# min                0.000000               0.000000              0.000000
# 25%                0.000000               0.000000              0.002000
# 50%                0.000000               0.000000              0.003000
# 75%                0.001000               0.001000              0.004000
# max                0.074000               0.012000              0.076000
#
#        system.cpu.user.pct  ...  system.memory.hugepages.used.pct  \
# count          1077.000000  ...                            1079.0
# mean              0.002519  ...                               0.0
# std               0.002568  ...                               0.0
# min               0.000000  ...                               0.0
# 25%               0.001000  ...                               0.0
# 50%               0.002000  ...                               0.0
# 75%               0.003000  ...                               0.0
# max               0.053000  ...                               0.0
#
#        system.memory.swap.free  system.memory.swap.in.pages  \
# count                   1079.0                       1079.0
# mean                       0.0                          0.0
# std                        0.0                          0.0
# min                        0.0                          0.0
# 25%                        0.0                          0.0
# 50%                        0.0                          0.0
# 75%                        0.0                          0.0
# max                        0.0                          0.0
#
#        system.memory.swap.out.pages  system.memory.swap.readahead.cached  \
# count                        1079.0                               1079.0
# mean                            0.0                                  0.0
# std                             0.0                                  0.0
# min                             0.0                                  0.0
# 25%                             0.0                                  0.0
# 50%                             0.0                                  0.0
# 75%                             0.0                                  0.0
# max                             0.0                                  0.0
#
#        system.memory.swap.readahead.pages  system.memory.swap.total  \
# count                              1079.0                    1079.0
# mean                                  0.0                       0.0
# std                                   0.0                       0.0
# min                                   0.0                       0.0
# 25%                                   0.0                       0.0
# 50%                                   0.0                       0.0
# 75%                                   0.0                       0.0
# max                                   0.0                       0.0
#
#        system.memory.swap.used.bytes  system.memory.swap.used.pct  \
# count                         1079.0                       1079.0
# mean                             0.0                          0.0
# std                              0.0                          0.0
# min                              0.0                          0.0
# 25%                              0.0                          0.0
# 50%                              0.0                          0.0
# 75%                              0.0                          0.0
# max                              0.0                          0.0
#
#        system.memory.used.pct
# count             1079.000000
# mean                 0.890065
# std                  0.031357
# min                  0.792000
# 25%                  0.870000
# 50%                  0.893000
# 75%                  0.920000
# max                  0.933000
#
# [8 rows x 28 columns]

# %%
df_cpu = df[cpu_cols].dropna()
df_memory = df[memory_cols].dropna()

# %%
print(df_cpu.shape)
print(df_memory.shape)
# Out:
# (1077, 11)
# (1079, 24)

# %% [markdown]
# ## DBSCAN CPU

# %%
for col in df_cpu.columns.values:
    df_cpu[col] = df_cpu[col].astype(str).str.replace(',', '').astype(float)
df_cpu.describe()
# Out:
#        event.duration  system.cpu.cores  system.cpu.idle.pct  \
# count     1077.000000            1077.0          1077.000000
# mean    212214.739090               1.0             0.992766
# std      30727.582863               0.0             0.060790
# min     134343.000000               1.0             0.000000
# 25%     197382.000000               1.0             0.996000
# 50%     212141.000000               1.0             0.997000
# 75%     223691.000000               1.0             0.998000
# max     647705.000000               1.0             1.000000
#
#        system.cpu.iowait.pct  system.cpu.irq.pct  system.cpu.nice.pct  \
# count            1077.000000              1077.0               1077.0
# mean                0.000072                 0.0                  0.0
# std                 0.000434                 0.0                  0.0
# min                 0.000000                 0.0                  0.0
# 25%                 0.000000                 0.0                  0.0
# 50%                 0.000000                 0.0                  0.0
# 75%                 0.000000                 0.0                  0.0
# max                 0.010000                 0.0                  0.0
#
#        system.cpu.softirq.pct  system.cpu.steal.pct  system.cpu.system.pct  \
# count             1077.000000           1077.000000            1077.000000
# mean                 0.000027              0.000551               0.000352
# std                  0.000162              0.002893               0.000658
# min                  0.000000              0.000000               0.000000
# 25%                  0.000000              0.000000               0.000000
# 50%                  0.000000              0.000000               0.000000
# 75%                  0.000000              0.001000               0.001000
# max                  0.001000              0.074000               0.012000
#
#        system.cpu.total.pct  system.cpu.user.pct
# count           1077.000000          1077.000000
# mean               0.003448             0.002519
# std                0.004122             0.002568
# min                0.000000             0.000000
# 25%                0.002000             0.001000
# 50%                0.003000             0.002000
# 75%                0.004000             0.003000
# max                0.076000             0.053000

# %%
df_cpu = df_cpu.drop(['system.cpu.cores', 'system.cpu.irq.pct', 'system.cpu.nice.pct'], axis=1)
df_cpu.describe()
# Out:
#        event.duration  system.cpu.idle.pct  system.cpu.iowait.pct  \
# count     1077.000000          1077.000000            1077.000000
# mean    212214.739090             0.992766               0.000072
# std      30727.582863             0.060790               0.000434
# min     134343.000000             0.000000               0.000000
# 25%     197382.000000             0.996000               0.000000
# 50%     212141.000000             0.997000               0.000000
# 75%     223691.000000             0.998000               0.000000
# max     647705.000000             1.000000               0.010000
#
#        system.cpu.softirq.pct  system.cpu.steal.pct  system.cpu.system.pct  \
# count             1077.000000           1077.000000            1077.000000
# mean                 0.000027              0.000551               0.000352
# std                  0.000162              0.002893               0.000658
# min                  0.000000              0.000000               0.000000
# 25%                  0.000000              0.000000               0.000000
# 50%                  0.000000              0.000000               0.000000
# 75%                  0.000000              0.001000               0.001000
# max                  0.001000              0.074000               0.012000
#
#        system.cpu.total.pct  system.cpu.user.pct
# count           1077.000000          1077.000000
# mean               0.003448             0.002519
# std                0.004122             0.002568
# min                0.000000             0.000000
# 25%                0.002000             0.001000
# 50%                0.003000             0.002000
# 75%                0.004000             0.003000
# max                0.076000             0.053000

# %%
from sklearn.preprocessing import StandardScaler

df_cpu_scalled = StandardScaler().fit_transform(df_cpu)

df_cpu_scalled = pd.DataFrame(df_cpu_scalled, columns=df_cpu.columns.values)
df_cpu_scalled.head()
# Out:
#    event.duration  system.cpu.idle.pct  system.cpu.iowait.pct  \
# 0        0.463488             0.053224              -0.167084
# 1       -0.726061             0.086140              -0.167084
# 2        0.895223             0.053224              -0.167084
# 3       -0.270591             0.086140              -0.167084
# 4        0.698403             0.053224              -0.167084
#
#    system.cpu.softirq.pct  system.cpu.steal.pct  system.cpu.system.pct  \
# 0               -0.166348             -0.190380              -0.535194
# 1               -0.166348             -0.190380              -0.535194
# 2               -0.166348              0.155386              -0.535194
# 3               -0.166348             -0.190380               0.985661
# 4               -0.166348             -0.190380              -0.535194
#
#    system.cpu.total.pct  system.cpu.user.pct
# 0              0.134097             0.577007
# 1             -0.351356            -0.202224
# 2              0.134097             0.187392
# 3             -0.351356            -0.591839
# 4              0.134097             0.577007

# %%
from sklearn.cluster import DBSCAN

db_model = DBSCAN(eps=3, min_samples=10).fit(df_cpu_scalled)
core_samples_mask = np.zeros_like(db_model.labels_, dtype=bool)
core_samples_mask[db_model.core_sample_indices_] = True
labels = db_model.labels_

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 2
# Estimated number of noise points: 13

# %%
# Plot result
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
plt.figure(figsize=(15,8))
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = df_cpu_scalled[class_member_mask & core_samples_mask]
   
    plt.plot(xy.iloc[:, 0], xy.iloc[:, 1], 'o', markerfacecolor=tuple(col), markeredgecolor='k', markersize=8)

    xy = df_cpu_scalled[class_member_mask & ~core_samples_mask]
    plt.plot(xy.iloc[:, 0], xy.iloc[:, 1], 'o', markerfacecolor=tuple(col), markeredgecolor='k', markersize=4)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %%
import collections

collections.Counter(db_model.labels_)
# Out:
# Counter({0: 28,
#          1: 169,
#          -1: 416,
#          2: 56,
#          3: 65,
#          4: 110,
#          8: 21,
#          5: 50,
#          6: 68,
#          9: 14,
#          13: 12,
#          7: 36,
#          12: 9,
#          10: 10,
#          11: 13})
