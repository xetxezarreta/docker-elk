# %% [markdown]
# ### PACKETBEAT

# %%
import pandas as pd

df = pd.read_csv('data/data_packetbeat.csv', low_memory=False)
df
# Out:
#                         @timestamp  @version                   _id  \
# 0      Jan 13, 2020 @ 14:19:10.001         1  5BVFn28B3Y26iTaw0weI
# 1      Jan 13, 2020 @ 14:19:10.001         1  5RVFn28B3Y26iTaw0weI
# 2      Jan 13, 2020 @ 14:19:10.001         1  9xVFn28B3Y26iTaw0weJ
# 3      Jan 13, 2020 @ 14:19:10.001         1  5xVFn28B3Y26iTaw0weI
# 4      Jan 13, 2020 @ 14:19:10.001         1  -RVFn28B3Y26iTaw0weJ
# ...                            ...       ...                   ...
# 12555  Jan 13, 2020 @ 12:59:00.005         1  jRT8nm8B3Y26iTawbq-D
# 12556  Jan 13, 2020 @ 12:59:00.005         1  lhT8nm8B3Y26iTawbq-E
# 12557  Jan 13, 2020 @ 12:59:00.005         1  lxT8nm8B3Y26iTawbq-E
# 12558  Jan 13, 2020 @ 12:59:00.005         1  mBT8nm8B3Y26iTawbq-E
# 12559  Jan 13, 2020 @ 12:59:00.005         1  mRT8nm8B3Y26iTawbq-E
#
#                            _index  _score _type  \
# 0      logstash-2020.01.13-000001     NaN  _doc
# 1      logstash-2020.01.13-000001     NaN  _doc
# 2      logstash-2020.01.13-000001     NaN  _doc
# 3      logstash-2020.01.13-000001     NaN  _doc
# 4      logstash-2020.01.13-000001     NaN  _doc
# ...                           ...     ...   ...
# 12555  logstash-2020.01.13-000001     NaN  _doc
# 12556  logstash-2020.01.13-000001     NaN  _doc
# 12557  logstash-2020.01.13-000001     NaN  _doc
# 12558  logstash-2020.01.13-000001     NaN  _doc
# 12559  logstash-2020.01.13-000001     NaN  _doc
#
#                          agent.ephemeral_id                 agent.hostname  \
# 0      0189a605-49eb-4a0f-bb7d-861415811ba2  ip-172-31-91-217.ec2.internal
# 1      0189a605-49eb-4a0f-bb7d-861415811ba2  ip-172-31-91-217.ec2.internal
# 2      0189a605-49eb-4a0f-bb7d-861415811ba2  ip-172-31-91-217.ec2.internal
# 3      0189a605-49eb-4a0f-bb7d-861415811ba2  ip-172-31-91-217.ec2.internal
# 4      0189a605-49eb-4a0f-bb7d-861415811ba2  ip-172-31-91-217.ec2.internal
# ...                                     ...                            ...
# 12555  0189a605-49eb-4a0f-bb7d-861415811ba2  ip-172-31-91-217.ec2.internal
# 12556  0189a605-49eb-4a0f-bb7d-861415811ba2  ip-172-31-91-217.ec2.internal
# 12557  0189a605-49eb-4a0f-bb7d-861415811ba2  ip-172-31-91-217.ec2.internal
# 12558  0189a605-49eb-4a0f-bb7d-861415811ba2  ip-172-31-91-217.ec2.internal
# 12559  0189a605-49eb-4a0f-bb7d-861415811ba2  ip-172-31-91-217.ec2.internal
#
#                                    agent.id  agent.type  ... server.bytes  \
# 0      a5733220-289e-45c3-bea9-0c7a5cdd3335  packetbeat  ...          NaN
# 1      a5733220-289e-45c3-bea9-0c7a5cdd3335  packetbeat  ...          NaN
# 2      a5733220-289e-45c3-bea9-0c7a5cdd3335  packetbeat  ...          NaN
# 3      a5733220-289e-45c3-bea9-0c7a5cdd3335  packetbeat  ...          NaN
# 4      a5733220-289e-45c3-bea9-0c7a5cdd3335  packetbeat  ...          NaN
# ...                                     ...         ...  ...          ...
# 12555  a5733220-289e-45c3-bea9-0c7a5cdd3335  packetbeat  ...          NaN
# 12556  a5733220-289e-45c3-bea9-0c7a5cdd3335  packetbeat  ...          NaN
# 12557  a5733220-289e-45c3-bea9-0c7a5cdd3335  packetbeat  ...          NaN
# 12558  a5733220-289e-45c3-bea9-0c7a5cdd3335  packetbeat  ...          NaN
# 12559  a5733220-289e-45c3-bea9-0c7a5cdd3335  packetbeat  ...          NaN
#
#        server.ip server.port source.bytes        source.ip source.packets  \
# 0            NaN         NaN       23,080    193.146.78.93          335.0
# 1            NaN         NaN          112     92.118.37.99            2.0
# 2            NaN         NaN        1,848  203.114.235.170           15.0
# 3            NaN         NaN        1,792  203.114.235.170           14.0
# 4            NaN         NaN        1,848  203.114.235.170           15.0
# ...          ...         ...          ...              ...            ...
# 12555        NaN         NaN           90    172.31.91.217            1.0
# 12556        NaN         NaN           90    172.31.91.217            1.0
# 12557        NaN         NaN           92    172.31.91.217            1.0
# 12558        NaN         NaN           90    172.31.91.217            1.0
# 12559        NaN         NaN           92    172.31.91.217            1.0
#
#       source.port status                       tags  type
# 0          34,039    NaN  ["beats_input_raw_event"]  flow
# 1          43,304    NaN  ["beats_input_raw_event"]  flow
# 2          58,721    NaN  ["beats_input_raw_event"]  flow
# 3          51,308    NaN  ["beats_input_raw_event"]  flow
# 4           8,913    NaN  ["beats_input_raw_event"]  flow
# ...           ...    ...                        ...   ...
# 12555      59,178    NaN  ["beats_input_raw_event"]  flow
# 12556      51,406    NaN  ["beats_input_raw_event"]  flow
# 12557      45,786    NaN  ["beats_input_raw_event"]  flow
# 12558      45,017    NaN  ["beats_input_raw_event"]  flow
# 12559      49,985    NaN  ["beats_input_raw_event"]  flow
#
# [12560 rows x 84 columns]

# %%
df = df.dropna(axis=1, how = 'all')
#df = df.drop(['@version','network.direction', 'dns.type', '_type', 'client.bytes','dns.answers_count', 'dns.authorities_count','dns.flags.authentic_data', 'client.ip', 'client.port','server.bytes', 'server.ip', 'server.port', '_id', '_index', '_type', 'agent.ephemeral_id', 'agent.hostname', 'agent.id', 'agent.version', 'cloud.account.id', 'cloud.availability_zone', 'cloud.image.id', 'cloud.instance.id', 'cloud.machine.type', 'cloud.provider', 'cloud.region', 'ecs.version', 'event.kind', 'host.architecture', 'host.containerized', 'host.os.name', 'host.os.platform', 'dns.additionals_count', 'dns.flags.authoritative', 'dns.flags.checking_disabled', 'dns.flags.recursion_available', 'dns.flags.recursion_desired','dns.flags.truncated_response','dns.header_flags', 'dns.id', 'query', 'resource', 'dns.question.class', 'dns.question.etld_plus_one', 'dns.question.name', 'network.protocol', 'dns.op_code', 'dns.question.registered_domain', 'dns.question.type','dns.response_code', 'status', 'event.action', 'event.category', 'tags', 'type', 'network.type', 'host.hostname', 'host.name', 'host.os.codename', 'host.os.family','host.os.kernel', 'host.os.version', 'method', 'flow.id', 'network.community_id', 'flow.final'], axis=1)
df = df[['@timestamp', 'source.bytes', 'source.packets','destination.bytes', 'destination.packets', 'network.packets', 'network.bytes', 'network.transport', 'event.duration']]
df
# Out:
#                         @timestamp source.bytes  source.packets  \
# 0      Jan 13, 2020 @ 14:19:10.001       23,080           335.0
# 1      Jan 13, 2020 @ 14:19:10.001          112             2.0
# 2      Jan 13, 2020 @ 14:19:10.001        1,848            15.0
# 3      Jan 13, 2020 @ 14:19:10.001        1,792            14.0
# 4      Jan 13, 2020 @ 14:19:10.001        1,848            15.0
# ...                            ...          ...             ...
# 12555  Jan 13, 2020 @ 12:59:00.005           90             1.0
# 12556  Jan 13, 2020 @ 12:59:00.005           90             1.0
# 12557  Jan 13, 2020 @ 12:59:00.005           92             1.0
# 12558  Jan 13, 2020 @ 12:59:00.005           90             1.0
# 12559  Jan 13, 2020 @ 12:59:00.005           92             1.0
#
#       destination.bytes  destination.packets network.packets network.bytes  \
# 0               307,728                327.0             662       330,808
# 1                    56                  1.0               3           168
# 2                 2,289                 10.0              25         4,137
# 3                 2,289                 10.0              24         4,081
# 4                 2,289                 10.0              25         4,137
# ...                 ...                  ...             ...           ...
# 12555               178                  1.0               2           268
# 12556               178                  1.0               2           268
# 12557                92                  1.0               2           184
# 12558               178                  1.0               2           268
# 12559                92                  1.0               2           184
#
#       network.transport     event.duration
# 0                   tcp  9,149,952,108,596
# 1                   tcp             87,498
# 2                   tcp      5,632,239,245
# 3                   tcp      3,583,794,677
# 4                   tcp      4,096,117,409
# ...                 ...                ...
# 12555               udp             92,675
# 12556               udp            103,432
# 12557               udp             49,203
# 12558               udp             92,502
# 12559               udp             52,203
#
# [12560 rows x 9 columns]

# %%
df = df.sort_values(by='@timestamp')
df = df.reset_index()
del df['index']
df = df[['source.bytes', 'source.packets','destination.bytes', 'destination.packets', 'network.packets', 'network.bytes', 'network.transport', 'event.duration']]
df

# %%
for row in df:

# %%
import calendar
from datetime import datetime
import datetime
import time

split = df['@timestamp'][1].split()
split[1] = split[1].replace(',', '')
split

abbr_to_num = {name: num for num, name in enumerate(calendar.month_abbr) if num}
date = str(split[2]) + "-" + str(abbr_to_num[split[0]]) + "-" + str(split[1]) + str(split[4])

time = split[4].split(":")
mil = time[2].split(".")

# %%
x = datetime.datetime(int(split[2]), int(abbr_to_num[split[0]]), int(split[1]), int(time[0]), int(time[1]), int(mil[0]), int(mil[1]))
#timestamp = time.mktime(dt.timetuple())
#print(timestamp)
#timestamp = datetime.timestamp(x)
#print("timestamp =", timestamp)
timestamp = x.timestamp()
timestamp
# Out:
# 1578916740.000005

# %% [markdown]
# ### HONEYPOT

# %%
df_hon = pd.read_csv('data/data_honeypot.csv', low_memory=False)
df_hon
# Out:
#                           @timestamp  @version                   _id  \
# 0     January 9th 2020, 09:44:10.927         1  oYmwiW8BqsQZih0opyJ1
# 1     January 9th 2020, 09:44:10.927         1  oomwiW8BqsQZih0opyJ1
# 2     January 9th 2020, 09:44:10.927         1  pYmwiW8BqsQZih0opyJ1
# 3     January 9th 2020, 09:44:10.927         1  rImwiW8BqsQZih0opyJ1
# 4     January 9th 2020, 09:44:10.927         1  rYmwiW8BqsQZih0opyJ1
# ...                              ...       ...                   ...
# 9701  January 9th 2020, 09:29:05.636         1  44iiiW8BqsQZih0o0fyN
# 9702  January 9th 2020, 09:29:05.636         1  5IiiiW8BqsQZih0o0fyN
# 9703  January 9th 2020, 09:29:05.636         1  5oiiiW8BqsQZih0o0fyN
# 9704  January 9th 2020, 09:29:05.636         1  54iiiW8BqsQZih0o0fyN
# 9705  January 9th 2020, 09:29:05.636         1  6YiiiW8BqsQZih0o0fyN
#
#                   _index  _score _type     beat.hostname         beat.name  \
# 0     dionaea-2020.01.09     NaN   doc  ip-172-31-88-210  ip-172-31-88-210
# 1     dionaea-2020.01.09     NaN   doc  ip-172-31-88-210  ip-172-31-88-210
# 2     dionaea-2020.01.09     NaN   doc  ip-172-31-88-210  ip-172-31-88-210
# 3     dionaea-2020.01.09     NaN   doc  ip-172-31-88-210  ip-172-31-88-210
# 4     dionaea-2020.01.09     NaN   doc  ip-172-31-88-210  ip-172-31-88-210
# ...                  ...     ...   ...               ...               ...
# 9701  dionaea-2020.01.09     NaN   doc  ip-172-31-88-210  ip-172-31-88-210
# 9702  dionaea-2020.01.09     NaN   doc  ip-172-31-88-210  ip-172-31-88-210
# 9703  dionaea-2020.01.09     NaN   doc  ip-172-31-88-210  ip-172-31-88-210
# 9704  dionaea-2020.01.09     NaN   doc  ip-172-31-88-210  ip-172-31-88-210
# 9705  dionaea-2020.01.09     NaN   doc  ip-172-31-88-210  ip-172-31-88-210
#
#      beat.version connection  ...  mssql_fingerprint  \
# 0           6.6.0    269,339  ...            268,252
# 1           6.6.0    269,342  ...            268,253
# 2           6.6.0    269,345  ...            268,256
# 3           6.6.0    269,352  ...            268,263
# 4           6.6.0    269,354  ...            268,264
# ...           ...        ...  ...                ...
# 9701        6.6.0    264,438  ...            263,371
# 9702        6.6.0    264,439  ...            263,372
# 9703        6.6.0    264,441  ...            263,374
# 9704        6.6.0    264,443  ...            263,375
# 9705        6.6.0    264,442  ...            263,377
#
#      mssql_fingerprint_appname mssql_fingerprint_cltintname  \
# 0                          NaN                        OLEDB
# 1                          NaN                        OLEDB
# 2                          NaN                        OLEDB
# 3                          NaN                        OLEDB
# 4                          NaN                        OLEDB
# ...                        ...                          ...
# 9701                       NaN                        OLEDB
# 9702                       NaN                        OLEDB
# 9703                       NaN                        OLEDB
# 9704                       NaN                        OLEDB
# 9705                       NaN                        OLEDB
#
#      mssql_fingerprint_hostname prospector.type     remote_host  \
# 0                      DUONGKHA             log  113.161.194.96
# 1               USER-20190613CL             log   113.61.47.184
# 2               USER-20190613CL             log   113.61.47.184
# 3                      DUONGKHA             log  113.161.194.96
# 4               USER-20190613CL             log   113.61.47.184
# ...                         ...             ...             ...
# 9701                   DUONGKHA             log  113.161.194.96
# 9702            USER-20190613CL             log   113.61.47.184
# 9703                  LENOVO-PC             log   36.72.218.112
# 9704            USER-20190613CL             log   113.61.47.184
# 9705                   DUONGKHA             log  113.161.194.96
#
#                                         remote_hostname remote_port tags  \
# 0                                        static.vnpt.vn      53,552   []
# 1     184.47.61.113.accent.inet.static.eastern-tele.com      56,479   []
# 2     184.47.61.113.accent.inet.static.eastern-tele.com      56,610   []
# 3                                        static.vnpt.vn      55,365   []
# 4     184.47.61.113.accent.inet.static.eastern-tele.com      57,113   []
# ...                                                 ...         ...  ...
# 9701                                     static.vnpt.vn      64,105   []
# 9702  184.47.61.113.accent.inet.static.eastern-tele.com      64,967   []
# 9703                                      36.72.218.112      52,670   []
# 9704  184.47.61.113.accent.inet.static.eastern-tele.com      65,111   []
# 9705                                     static.vnpt.vn      64,620   []
#
#                            timestamp
# 0     January 9th 2020, 09:43:50.529
# 1     January 9th 2020, 09:43:51.288
# 2     January 9th 2020, 09:43:51.977
# 3     January 9th 2020, 09:43:53.954
# 4     January 9th 2020, 09:43:54.635
# ...                              ...
# 9701  January 9th 2020, 09:28:03.542
# 9702  January 9th 2020, 09:28:03.785
# 9703  January 9th 2020, 09:28:04.042
# 9704  January 9th 2020, 09:28:04.501
# 9705  January 9th 2020, 09:28:04.460
#
# [9706 rows x 49 columns]

# %%
df_hon = df_hon.dropna(axis=1, how = 'all')
df_hon
# Out:
#                           @timestamp  @version                   _id  \
# 0     January 9th 2020, 09:44:10.927         1  oYmwiW8BqsQZih0opyJ1
# 1     January 9th 2020, 09:44:10.927         1  oomwiW8BqsQZih0opyJ1
# 2     January 9th 2020, 09:44:10.927         1  pYmwiW8BqsQZih0opyJ1
# 3     January 9th 2020, 09:44:10.927         1  rImwiW8BqsQZih0opyJ1
# 4     January 9th 2020, 09:44:10.927         1  rYmwiW8BqsQZih0opyJ1
# ...                              ...       ...                   ...
# 9701  January 9th 2020, 09:29:05.636         1  44iiiW8BqsQZih0o0fyN
# 9702  January 9th 2020, 09:29:05.636         1  5IiiiW8BqsQZih0o0fyN
# 9703  January 9th 2020, 09:29:05.636         1  5oiiiW8BqsQZih0o0fyN
# 9704  January 9th 2020, 09:29:05.636         1  54iiiW8BqsQZih0o0fyN
# 9705  January 9th 2020, 09:29:05.636         1  6YiiiW8BqsQZih0o0fyN
#
#                   _index _type     beat.hostname         beat.name  \
# 0     dionaea-2020.01.09   doc  ip-172-31-88-210  ip-172-31-88-210
# 1     dionaea-2020.01.09   doc  ip-172-31-88-210  ip-172-31-88-210
# 2     dionaea-2020.01.09   doc  ip-172-31-88-210  ip-172-31-88-210
# 3     dionaea-2020.01.09   doc  ip-172-31-88-210  ip-172-31-88-210
# 4     dionaea-2020.01.09   doc  ip-172-31-88-210  ip-172-31-88-210
# ...                  ...   ...               ...               ...
# 9701  dionaea-2020.01.09   doc  ip-172-31-88-210  ip-172-31-88-210
# 9702  dionaea-2020.01.09   doc  ip-172-31-88-210  ip-172-31-88-210
# 9703  dionaea-2020.01.09   doc  ip-172-31-88-210  ip-172-31-88-210
# 9704  dionaea-2020.01.09   doc  ip-172-31-88-210  ip-172-31-88-210
# 9705  dionaea-2020.01.09   doc  ip-172-31-88-210  ip-172-31-88-210
#
#      beat.version connection connection_protocol  ... mssql_fingerprint  \
# 0           6.6.0    269,339              mssqld  ...           268,252
# 1           6.6.0    269,342              mssqld  ...           268,253
# 2           6.6.0    269,345              mssqld  ...           268,256
# 3           6.6.0    269,352              mssqld  ...           268,263
# 4           6.6.0    269,354              mssqld  ...           268,264
# ...           ...        ...                 ...  ...               ...
# 9701        6.6.0    264,438              mssqld  ...           263,371
# 9702        6.6.0    264,439              mssqld  ...           263,372
# 9703        6.6.0    264,441              mssqld  ...           263,374
# 9704        6.6.0    264,443              mssqld  ...           263,375
# 9705        6.6.0    264,442              mssqld  ...           263,377
#
#      mssql_fingerprint_appname mssql_fingerprint_cltintname  \
# 0                          NaN                        OLEDB
# 1                          NaN                        OLEDB
# 2                          NaN                        OLEDB
# 3                          NaN                        OLEDB
# 4                          NaN                        OLEDB
# ...                        ...                          ...
# 9701                       NaN                        OLEDB
# 9702                       NaN                        OLEDB
# 9703                       NaN                        OLEDB
# 9704                       NaN                        OLEDB
# 9705                       NaN                        OLEDB
#
#      mssql_fingerprint_hostname prospector.type     remote_host  \
# 0                      DUONGKHA             log  113.161.194.96
# 1               USER-20190613CL             log   113.61.47.184
# 2               USER-20190613CL             log   113.61.47.184
# 3                      DUONGKHA             log  113.161.194.96
# 4               USER-20190613CL             log   113.61.47.184
# ...                         ...             ...             ...
# 9701                   DUONGKHA             log  113.161.194.96
# 9702            USER-20190613CL             log   113.61.47.184
# 9703                  LENOVO-PC             log   36.72.218.112
# 9704            USER-20190613CL             log   113.61.47.184
# 9705                   DUONGKHA             log  113.161.194.96
#
#                                         remote_hostname remote_port tags  \
# 0                                        static.vnpt.vn      53,552   []
# 1     184.47.61.113.accent.inet.static.eastern-tele.com      56,479   []
# 2     184.47.61.113.accent.inet.static.eastern-tele.com      56,610   []
# 3                                        static.vnpt.vn      55,365   []
# 4     184.47.61.113.accent.inet.static.eastern-tele.com      57,113   []
# ...                                                 ...         ...  ...
# 9701                                     static.vnpt.vn      64,105   []
# 9702  184.47.61.113.accent.inet.static.eastern-tele.com      64,967   []
# 9703                                      36.72.218.112      52,670   []
# 9704  184.47.61.113.accent.inet.static.eastern-tele.com      65,111   []
# 9705                                     static.vnpt.vn      64,620   []
#
#                            timestamp
# 0     January 9th 2020, 09:43:50.529
# 1     January 9th 2020, 09:43:51.288
# 2     January 9th 2020, 09:43:51.977
# 3     January 9th 2020, 09:43:53.954
# 4     January 9th 2020, 09:43:54.635
# ...                              ...
# 9701  January 9th 2020, 09:28:03.542
# 9702  January 9th 2020, 09:28:03.785
# 9703  January 9th 2020, 09:28:04.042
# 9704  January 9th 2020, 09:28:04.501
# 9705  January 9th 2020, 09:28:04.460
#
# [9706 rows x 47 columns]

# %%
df_hon = df_hon.drop(['@version','_index', '_type', 'beat.hostname', 'beat.name', 'beat.version', 'connection_protocol', 'document_type', 'mssql_fingerprint_appname', 'tags'], axis=1)
df_hon
# Out:
#                           @timestamp                   _id connection  \
# 0     January 9th 2020, 09:44:10.927  oYmwiW8BqsQZih0opyJ1    269,339
# 1     January 9th 2020, 09:44:10.927  oomwiW8BqsQZih0opyJ1    269,342
# 2     January 9th 2020, 09:44:10.927  pYmwiW8BqsQZih0opyJ1    269,345
# 3     January 9th 2020, 09:44:10.927  rImwiW8BqsQZih0opyJ1    269,352
# 4     January 9th 2020, 09:44:10.927  rYmwiW8BqsQZih0opyJ1    269,354
# ...                              ...                   ...        ...
# 9701  January 9th 2020, 09:29:05.636  44iiiW8BqsQZih0o0fyN    264,438
# 9702  January 9th 2020, 09:29:05.636  5IiiiW8BqsQZih0o0fyN    264,439
# 9703  January 9th 2020, 09:29:05.636  5oiiiW8BqsQZih0o0fyN    264,441
# 9704  January 9th 2020, 09:29:05.636  54iiiW8BqsQZih0o0fyN    264,443
# 9705  January 9th 2020, 09:29:05.636  6YiiiW8BqsQZih0o0fyN    264,442
#
#      connection_root connection_transport connection_type            eventid  \
# 0            269,339                  tcp          accept  mssql_fingerprint
# 1            269,342                  tcp          accept  mssql_fingerprint
# 2            269,345                  tcp          accept  mssql_fingerprint
# 3            269,352                  tcp          accept  mssql_fingerprint
# 4            269,354                  tcp          accept  mssql_fingerprint
# ...              ...                  ...             ...                ...
# 9701         264,438                  tcp          accept  mssql_fingerprint
# 9702         264,439                  tcp          accept  mssql_fingerprint
# 9703         264,441                  tcp          accept  mssql_fingerprint
# 9704         264,443                  tcp          accept  mssql_fingerprint
# 9705         264,442                  tcp          accept  mssql_fingerprint
#
#      geoip.city_name geoip.continent_code geoip.country_code2  ...  \
# 0              Hanoi                   AS                  VN  ...
# 1                NaN                   AS                  PH  ...
# 2                NaN                   AS                  PH  ...
# 3              Hanoi                   AS                  VN  ...
# 4                NaN                   AS                  PH  ...
# ...              ...                  ...                 ...  ...
# 9701           Hanoi                   AS                  VN  ...
# 9702             NaN                   AS                  PH  ...
# 9703       Sitimulyo                   AS                  ID  ...
# 9704             NaN                   AS                  PH  ...
# 9705           Hanoi                   AS                  VN  ...
#
#      login_username                                            message  \
# 0               NaN  {"local_host": "172.31.88.210", "mssql_fingerp...
# 1               NaN  {"local_host": "172.31.88.210", "mssql_fingerp...
# 2               NaN  {"local_host": "172.31.88.210", "mssql_fingerp...
# 3               NaN  {"local_host": "172.31.88.210", "mssql_fingerp...
# 4               NaN  {"local_host": "172.31.88.210", "mssql_fingerp...
# ...             ...                                                ...
# 9701            NaN  {"mssql_fingerprint_cltintname": "OLEDB", "rem...
# 9702            NaN  {"mssql_fingerprint_cltintname": "OLEDB", "rem...
# 9703            NaN  {"mssql_fingerprint_cltintname": "OLEDB", "rem...
# 9704            NaN  {"mssql_fingerprint_cltintname": "OLEDB", "rem...
# 9705            NaN  {"mssql_fingerprint_cltintname": "OLEDB", "rem...
#
#      mssql_fingerprint  mssql_fingerprint_cltintname  \
# 0              268,252                         OLEDB
# 1              268,253                         OLEDB
# 2              268,256                         OLEDB
# 3              268,263                         OLEDB
# 4              268,264                         OLEDB
# ...                ...                           ...
# 9701           263,371                         OLEDB
# 9702           263,372                         OLEDB
# 9703           263,374                         OLEDB
# 9704           263,375                         OLEDB
# 9705           263,377                         OLEDB
#
#       mssql_fingerprint_hostname  prospector.type     remote_host  \
# 0                       DUONGKHA              log  113.161.194.96
# 1                USER-20190613CL              log   113.61.47.184
# 2                USER-20190613CL              log   113.61.47.184
# 3                       DUONGKHA              log  113.161.194.96
# 4                USER-20190613CL              log   113.61.47.184
# ...                          ...              ...             ...
# 9701                    DUONGKHA              log  113.161.194.96
# 9702             USER-20190613CL              log   113.61.47.184
# 9703                   LENOVO-PC              log   36.72.218.112
# 9704             USER-20190613CL              log   113.61.47.184
# 9705                    DUONGKHA              log  113.161.194.96
#
#                                         remote_hostname remote_port  \
# 0                                        static.vnpt.vn      53,552
# 1     184.47.61.113.accent.inet.static.eastern-tele.com      56,479
# 2     184.47.61.113.accent.inet.static.eastern-tele.com      56,610
# 3                                        static.vnpt.vn      55,365
# 4     184.47.61.113.accent.inet.static.eastern-tele.com      57,113
# ...                                                 ...         ...
# 9701                                     static.vnpt.vn      64,105
# 9702  184.47.61.113.accent.inet.static.eastern-tele.com      64,967
# 9703                                      36.72.218.112      52,670
# 9704  184.47.61.113.accent.inet.static.eastern-tele.com      65,111
# 9705                                     static.vnpt.vn      64,620
#
#                            timestamp
# 0     January 9th 2020, 09:43:50.529
# 1     January 9th 2020, 09:43:51.288
# 2     January 9th 2020, 09:43:51.977
# 3     January 9th 2020, 09:43:53.954
# 4     January 9th 2020, 09:43:54.635
# ...                              ...
# 9701  January 9th 2020, 09:28:03.542
# 9702  January 9th 2020, 09:28:03.785
# 9703  January 9th 2020, 09:28:04.042
# 9704  January 9th 2020, 09:28:04.501
# 9705  January 9th 2020, 09:28:04.460
#
# [9706 rows x 37 columns]

# %%
df_hon = df_hon.sort_values(by='timestamp')
df_hon = df_hon.reset_index()
del df_hon['index']
df_hon
# Out:
#                           @timestamp                   _id connection  \
# 0     January 9th 2020, 09:29:05.636  3oiiiW8BqsQZih0o0fyN    264,433
# 1     January 9th 2020, 09:29:05.636  4IiiiW8BqsQZih0o0fyN    264,435
# 2     January 9th 2020, 09:29:05.636  4YiiiW8BqsQZih0o0fyN    264,436
# 3     January 9th 2020, 09:29:05.636  44iiiW8BqsQZih0o0fyN    264,438
# 4     January 9th 2020, 09:29:05.636  5IiiiW8BqsQZih0o0fyN    264,439
# ...                              ...                   ...        ...
# 9701  January 9th 2020, 09:44:10.920  zomwiW8BqsQZih0opyE2    269,382
# 9702  January 9th 2020, 09:44:10.927  zImwiW8BqsQZih0oqSJr    269,383
# 9703  January 9th 2020, 09:44:10.920  zYmwiW8BqsQZih0opyE2    269,384
# 9704  January 9th 2020, 09:44:10.927  yomwiW8BqsQZih0oqSJr    269,384
# 9705  January 9th 2020, 09:44:10.927  z4mwiW8BqsQZih0oqSJr    269,385
#
#      connection_root connection_transport connection_type            eventid  \
# 0            264,433                  tcp          accept  mssql_fingerprint
# 1            264,435                  tcp          accept  mssql_fingerprint
# 2            264,436                  tcp          accept  mssql_fingerprint
# 3            264,438                  tcp          accept  mssql_fingerprint
# 4            264,439                  tcp          accept  mssql_fingerprint
# ...              ...                  ...             ...                ...
# 9701         269,382                  tcp          accept              login
# 9702         269,383                  tcp          accept  mssql_fingerprint
# 9703         269,384                  tcp          accept              login
# 9704         269,384                  tcp          accept  mssql_fingerprint
# 9705         269,385                  tcp          accept         connection
#
#      geoip.city_name geoip.continent_code geoip.country_code2  ...  \
# 0         Yogyakarta                   AS                  ID  ...
# 1                NaN                   AS                  PH  ...
# 2         Yogyakarta                   AS                  ID  ...
# 3              Hanoi                   AS                  VN  ...
# 4                NaN                   AS                  PH  ...
# ...              ...                  ...                 ...  ...
# 9701           Hanoi                   AS                  VN  ...
# 9702             NaN                   AS                  PH  ...
# 9703      Yogyakarta                   AS                  ID  ...
# 9704      Yogyakarta                   AS                  ID  ...
# 9705       Sitimulyo                   AS                  ID  ...
#
#      login_username                                            message  \
# 0               NaN  {"mssql_fingerprint_cltintname": "OLEDB", "rem...
# 1               NaN  {"mssql_fingerprint_cltintname": "OLEDB", "rem...
# 2               NaN  {"mssql_fingerprint_cltintname": "OLEDB", "rem...
# 3               NaN  {"mssql_fingerprint_cltintname": "OLEDB", "rem...
# 4               NaN  {"mssql_fingerprint_cltintname": "OLEDB", "rem...
# ...             ...                                                ...
# 9701             sa  {"local_host": "172.31.88.210", "connection": ...
# 9702            NaN  {"local_host": "172.31.88.210", "mssql_fingerp...
# 9703             sa  {"local_host": "172.31.88.210", "connection": ...
# 9704            NaN  {"local_host": "172.31.88.210", "mssql_fingerp...
# 9705            NaN  {"local_host": "172.31.88.210", "connection": ...
#
#      mssql_fingerprint  mssql_fingerprint_cltintname  \
# 0              263,366                         OLEDB
# 1              263,368                         OLEDB
# 2              263,369                         OLEDB
# 3              263,371                         OLEDB
# 4              263,372                         OLEDB
# ...                ...                           ...
# 9701               NaN                           NaN
# 9702           268,295                         OLEDB
# 9703               NaN                           NaN
# 9704           268,293                         OLEDB
# 9705               NaN                           NaN
#
#       mssql_fingerprint_hostname  prospector.type     remote_host  \
# 0                          AA-PC              log    119.2.52.239
# 1                     06ygnm1m50              log   113.61.47.184
# 2                     fvsdiv6a1g              log    119.2.52.239
# 3                       DUONGKHA              log  113.161.194.96
# 4                USER-20190613CL              log   113.61.47.184
# ...                          ...              ...             ...
# 9701                         NaN              log  113.161.194.96
# 9702             USER-20190613CL              log   113.61.47.184
# 9703                         NaN              log    119.2.52.239
# 9704                  uxw5jodpav              log    119.2.52.239
# 9705                         NaN              log   36.72.218.112
#
#                                         remote_hostname remote_port  \
# 0                             ipv4-239-52-2.as55666.net      62,491
# 1     184.47.61.113.accent.inet.static.eastern-tele.com      64,858
# 2                             ipv4-239-52-2.as55666.net      62,703
# 3                                        static.vnpt.vn      64,105
# 4     184.47.61.113.accent.inet.static.eastern-tele.com      64,967
# ...                                                 ...         ...
# 9701                                     static.vnpt.vn      59,860
# 9702  184.47.61.113.accent.inet.static.eastern-tele.com      58,498
# 9703                          ipv4-239-52-2.as55666.net      50,723
# 9704                          ipv4-239-52-2.as55666.net      50,723
# 9705                                      36.72.218.112      15,399
#
#                            timestamp
# 0     January 9th 2020, 09:28:02.637
# 1     January 9th 2020, 09:28:03.322
# 2     January 9th 2020, 09:28:03.451
# 3     January 9th 2020, 09:28:03.542
# 4     January 9th 2020, 09:28:03.785
# ...                              ...
# 9701  January 9th 2020, 09:44:01.712
# 9702  January 9th 2020, 09:44:01.923
# 9703  January 9th 2020, 09:44:01.930
# 9704  January 9th 2020, 09:44:01.930
# 9705  January 9th 2020, 09:44:02.265
#
# [9706 rows x 37 columns]

# %%
df_hon['geoip.city_name'].value_counts(dropna=False)
# Out:
# NaN           2864
# Sitimulyo     2314
# Hanoi         2155
# Yogyakarta    1976
# Astana         306
# Nanning         89
# Goyang-si        1
# Jeddah           1
# Name: geoip.city_name, dtype: int64

# %%
df_hon['login_username'].value_counts(dropna=False)
# Out:
# NaN    5096
# sa     4610
# Name: login_username, dtype: int64
